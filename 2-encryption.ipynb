# %% [markdown]
# # Client side code
#
# All regular Syftbox users will run code/API that looks something like this. Just read the public keys generated by the aggregators (verify they are the same), encrypt their data and publish it.

# %%
# Import required libraries
import os
from pathlib import Path

# Function to load public key from another datasite
def load_public_key(datasite):
    # Add the reading logic here
    
    return public_key

# Function to verify if multiple keys are identical
def verify_keys_match(aggregators):
    keys = []
    for aggregator in aggregators:
        key = load_public_key(aggreagtor)
        keys.append(key)
    
    # Check if all keys are identical
    return all(key == keys[0] for key in keys)

# Function to encrypt data using public key
def encrypt_data(public_key, data):
    # Code for encrypted data
    
    return encrypted

# Create output directory if it doesn't exist
output_dir = Path("encrypted_output")
output_dir.mkdir(exist_ok=True)

# List of paths where public keys are stored
aggreagtors = [
    "aggregator@openmined.org",
    "aggregator@orgA.org",
    "aggregator@orgB.org"
]

# Verify that all public keys match
if verify_keys_match(aggregators):
    print("All public keys match! Proceeding with encryption...")
    
    # Load the public key (we can use any of the verified keys)
    public_key = load_public_key(aggregators[0])
    
    # Sample data to encrypt
    sensitive_data = "This is sensitive information that needs to be encrypted"
    
    # Encrypt the data
    encrypted_data = encrypt_data(public_key, sensitive_data)
    
    # Write encrypted data to file
    output_file = output_dir / "encrypted_data.bin"
    with open(output_file, 'wb') as f:
        f.write(encrypted_data)
    
    print(f"Encrypted data has been written to {output_file}")
else:
    print("Error: Public keys do not match! Please verify your keys.")
